# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %matplotlib inline

# %%
data = np.loadtxt('plot.dat')
data.shape
# Out:
# (500, 7)

# %%
rlconf = data[:,0]
p1 = np.log(data[:,1])
p2 = np.log(data[:,2])
EKe =  np.log(data[:,3])
EKn =  np.log(data[:,4])
EKnu = np.log(data[:,5])
EKp = np.log(data[:,6])
# Out:
# /Users/charlesmartin14/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log

# %%
plt.plot(rlconf, p1, color='black')
plt.plot(rlconf, p2, color='cyan')
plt.plot(rlconf, EKe , color='magenta')
plt.plot(rlconf, EKnu, color='red' )
plt.plot(rlconf, EKn, color='blue')
plt.plot(rlconf, EKp, color='green')

patches = [mpatches.Patch(color='black', label='power 1'),
           mpatches.Patch(color='cyan', label='power 2'),
            mpatches.Patch(color='magenta', label='EKe'),
            mpatches.Patch(color='red', label='EKnu'),
            mpatches.Patch(color='blue', label='EKn'),
            mpatches.Patch(color='green', label='EKp')]
plt.legend(handles=patches)

plt.xlabel("Box confinment (log scale)")

from pylab import rcParams
rcParams['figure.figsize'] =10, 10
plt.show()
